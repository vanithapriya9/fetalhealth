# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\VANITHAPRIYA\\Data Science\\Projects'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C8EE-8223
#
#  Directory of C:\Users\VANITHAPRIYA\Data Science\Projects
#
# 04-10-2022  21:08    <DIR>          .
# 25-09-2022  21:50    <DIR>          ..
# 13-09-2022  14:03    <DIR>          .ipynb_checkpoints
# 04-10-2022  21:08         1,179,645 Fetal health.ipynb
# 13-09-2022  11:16           228,715 fetal_health.csv
#                2 File(s)      1,408,360 bytes
#                3 Dir(s)  112,503,959,552 bytes free

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
Fh=pd.read_csv("C:\\Users\\VANITHAPRIYA\\Data Science\\Projects\\fetal_health.csv")

# %%
Fh
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
Fh.dtypes
# Out:
# baseline value                                            float64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                           float64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability    float64
# mean_value_of_long_term_variability                       float64
# histogram_width                                           float64
# histogram_min                                             float64
# histogram_max                                             float64
# ...

# %%
Fh.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
Fh.shape
# Out:
# (2126, 22)

# %%
Fh.head(4)
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# ...

# %%
Fh.tail(4)
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# 2122                  0.0                   0.0                       0.0
# 2123                  0.0                   0.0                       0.0
# 2124                  0.0                   0.0                       0.0
# 2125                  0.0                   0.0                       0.0
#
#       abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 2122                             78.0                                   0.4
# ...

# %% [markdown]
#  # qualitative analysis

# %%
Fh.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
Fh.mean()
# Out:
# baseline value                                            133.303857
# accelerations                                               0.003178
# fetal_movement                                              0.009481
# uterine_contractions                                        0.004366
# light_decelerations                                         0.001889
# severe_decelerations                                        0.000003
# prolongued_decelerations                                    0.000159
# abnormal_short_term_variability                            46.990122
# mean_value_of_short_term_variability                        1.332785
# percentage_of_time_with_abnormal_long_term_variability      9.846660
# mean_value_of_long_term_variability                         8.187629
# histogram_width                                            70.445908
# histogram_min                                              93.579492
# histogram_max                                             164.025400
# ...

# %%
Fh.median()
# Out:
# baseline value                                            133.000
# accelerations                                               0.002
# fetal_movement                                              0.000
# uterine_contractions                                        0.004
# light_decelerations                                         0.000
# severe_decelerations                                        0.000
# prolongued_decelerations                                    0.000
# abnormal_short_term_variability                            49.000
# mean_value_of_short_term_variability                        1.200
# percentage_of_time_with_abnormal_long_term_variability      0.000
# mean_value_of_long_term_variability                         7.400
# histogram_width                                            67.500
# histogram_min                                              93.000
# histogram_max                                             162.000
# ...

# %%
Fh.mode()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           133.0            0.0             0.0                   0.0
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                  0.0                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             60.0                                   0.8
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                                0.0       ...           50.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          157.0                        1.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           133.0           143.0             146.0                 1.0
#
#    histogram_tendency  fetal_health
# ...

# %%
Fh.var()
# Out:
# baseline value                                            9.684222e+01
# accelerations                                             1.494279e-05
# fetal_movement                                            2.177701e-03
# uterine_contractions                                      8.679323e-06
# light_decelerations                                       8.762835e-06
# severe_decelerations                                      3.283272e-09
# prolongued_decelerations                                  3.480381e-07
# abnormal_short_term_variability                           2.955928e+02
# mean_value_of_short_term_variability                      7.801153e-01
# percentage_of_time_with_abnormal_long_term_variability    3.384452e+02
# mean_value_of_long_term_variability                       3.167716e+01
# histogram_width                                           1.517546e+03
# histogram_min                                             8.738061e+02
# ...

# %%
Fh.std()
# Out:
# baseline value                                             9.840844
# accelerations                                              0.003866
# fetal_movement                                             0.046666
# uterine_contractions                                       0.002946
# light_decelerations                                        0.002960
# severe_decelerations                                       0.000057
# prolongued_decelerations                                   0.000590
# abnormal_short_term_variability                           17.192814
# mean_value_of_short_term_variability                       0.883241
# percentage_of_time_with_abnormal_long_term_variability    18.396880
# mean_value_of_long_term_variability                        5.628247
# histogram_width                                           38.955693
# histogram_min                                             29.560212
# histogram_max                                             17.944183
# ...

# %%
Fh.min()
# Out:
# baseline value                                            106.0
# accelerations                                               0.0
# fetal_movement                                              0.0
# uterine_contractions                                        0.0
# light_decelerations                                         0.0
# severe_decelerations                                        0.0
# prolongued_decelerations                                    0.0
# abnormal_short_term_variability                            12.0
# mean_value_of_short_term_variability                        0.2
# percentage_of_time_with_abnormal_long_term_variability      0.0
# mean_value_of_long_term_variability                         0.0
# histogram_width                                             3.0
# histogram_min                                              50.0
# histogram_max                                             122.0
# histogram_number_of_peaks                                   0.0
# ...

# %%
Fh.max()
# Out:
# baseline value                                            160.000
# accelerations                                               0.019
# fetal_movement                                              0.481
# uterine_contractions                                        0.015
# light_decelerations                                         0.015
# severe_decelerations                                        0.001
# prolongued_decelerations                                    0.005
# abnormal_short_term_variability                            87.000
# mean_value_of_short_term_variability                        7.000
# percentage_of_time_with_abnormal_long_term_variability     91.000
# mean_value_of_long_term_variability                        50.700
# histogram_width                                           180.000
# histogram_min                                             159.000
# histogram_max                                             238.000
# ...

# %%
Range = Fh.max()-Fh.min()

# %%
Range
# Out:
# baseline value                                             54.000
# accelerations                                               0.019
# fetal_movement                                              0.481
# uterine_contractions                                        0.015
# light_decelerations                                         0.015
# severe_decelerations                                        0.001
# prolongued_decelerations                                    0.005
# abnormal_short_term_variability                            75.000
# mean_value_of_short_term_variability                        6.800
# percentage_of_time_with_abnormal_long_term_variability     91.000
# mean_value_of_long_term_variability                        50.700
# histogram_width                                           177.000
# histogram_min                                             109.000
# histogram_max                                             116.000
# ...

# %%
Fh.kurt()
# Out:
# baseline value                                             -0.292943
# accelerations                                               0.767648
# fetal_movement                                             64.260821
# uterine_contractions                                       -0.635071
# light_decelerations                                         2.517461
# severe_decelerations                                      299.424142
# prolongued_decelerations                                   20.515918
# abnormal_short_term_variability                            -1.051030
# mean_value_of_short_term_variability                        4.700756
# percentage_of_time_with_abnormal_long_term_variability      4.252998
# mean_value_of_long_term_variability                         4.131254
# histogram_width                                            -0.902287
# histogram_min                                              -1.290422
# histogram_max                                               0.632769
# ...

# %%
Fh.skew()
# Out:
# baseline value                                             0.020312
# accelerations                                              1.204392
# fetal_movement                                             7.811477
# uterine_contractions                                       0.159315
# light_decelerations                                        1.718437
# severe_decelerations                                      17.353457
# prolongued_decelerations                                   4.323965
# abnormal_short_term_variability                           -0.011829
# mean_value_of_short_term_variability                       1.657339
# percentage_of_time_with_abnormal_long_term_variability     2.195075
# mean_value_of_long_term_variability                        1.331998
# histogram_width                                            0.314235
# histogram_min                                              0.115784
# histogram_max                                              0.577862
# ...

# %% [markdown]
# # Missing values

# %%
Fh.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %% [markdown]
# # outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored

# %%
sns.boxplot(Fh['histogram_width'])
# Out:
# <AxesSubplot:xlabel='histogram_width'>

# %%
for i in Fh.columns:
    sns.distplot(Fh[i])
    print(i)
    plt.show()
# Out:
# baseline value
# accelerations
# fetal_movement
# uterine_contractions
# light_decelerations
# severe_decelerations
# prolongued_decelerations
# abnormal_short_term_variability
# mean_value_of_short_term_variability
# percentage_of_time_with_abnormal_long_term_variability
# mean_value_of_long_term_variability
# histogram_width
# histogram_min
# histogram_max
# histogram_number_of_peaks
# histogram_number_of_zeroes
# histogram_mode
# histogram_mean
# histogram_median
# histogram_variance
# histogram_tendency
# fetal_health

# %%
for i in Fh.columns:
    sns.displot(Fh[i])
    print(i)
    plt.show()
# Out:
# baseline value
# accelerations
# fetal_movement
# uterine_contractions
# light_decelerations
# severe_decelerations
# prolongued_decelerations
# abnormal_short_term_variability
# mean_value_of_short_term_variability
# percentage_of_time_with_abnormal_long_term_variability
# mean_value_of_long_term_variability
# histogram_width
# histogram_min
# histogram_max
# histogram_number_of_peaks
# histogram_number_of_zeroes
# histogram_mode
# histogram_mean
# histogram_median
# histogram_variance
# histogram_tendency
# fetal_health

# %%
for i in Fh.columns:
    sns.boxplot(Fh[i])
    print(i)
    plt.show()
# Out:
# baseline value
# accelerations
# fetal_movement
# uterine_contractions
# light_decelerations
# severe_decelerations
# prolongued_decelerations
# abnormal_short_term_variability
# mean_value_of_short_term_variability
# percentage_of_time_with_abnormal_long_term_variability
# mean_value_of_long_term_variability
# histogram_width
# histogram_min
# histogram_max
# histogram_number_of_peaks
# histogram_number_of_zeroes
# histogram_mode
# histogram_mean
# histogram_median
# histogram_variance
# histogram_tendency
# fetal_health

# %%
q1=Fh['histogram_mean'].quantile(0.25)
q3=Fh['histogram_mean'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d1=Fh[Fh['histogram_mean']<low].values
d2=Fh[Fh['histogram_mean']>high].values
Fh['histogram_mean'].replace(d1,low,inplace=True)
Fh['histogram_mean'].replace(d2,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_mean'])
# Out:
# <AxesSubplot:xlabel='histogram_mean'>

# %%
q1=Fh['histogram_median'].quantile(0.25)
q3=Fh['histogram_median'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d5=Fh[Fh['histogram_median']<low].values
d6=Fh[Fh['histogram_median']>high].values
Fh['histogram_median'].replace(d5,low,inplace=True)
Fh['histogram_median'].replace(d6,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_median'])
# Out:
# <AxesSubplot:xlabel='histogram_median'>

# %%
q1=Fh['histogram_variance'].quantile(0.25)
q3=Fh['histogram_variance'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d7=Fh[Fh['histogram_variance']<low].values
d8=Fh[Fh['histogram_variance']>high].values
Fh['histogram_variance'].replace(d7,low,inplace=True)
Fh['histogram_variance'].replace(d8,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_variance'])
# Out:
# <AxesSubplot:xlabel='histogram_variance'>

# %%
q1=Fh['histogram_mode'].quantile(0.25)
q3=Fh['histogram_mode'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d9=Fh[Fh['histogram_mode']<low].values
d10=Fh[Fh['histogram_mode']>high].values
Fh['histogram_mode'].replace(d9,low,inplace=True)
Fh['histogram_mode'].replace(d10,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_mode'])
# Out:
# <AxesSubplot:xlabel='histogram_mode'>

# %%
q1=Fh['histogram_max'].quantile(0.25)
q3=Fh['histogram_max'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d11=Fh[Fh['histogram_max']<low].values
d12=Fh[Fh['histogram_max']>high].values
Fh['histogram_max'].replace(d11,low,inplace=True)
Fh['histogram_max'].replace(d12,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_max'])
# Out:
# <AxesSubplot:xlabel='histogram_max'>

# %%
q1=Fh['histogram_min'].quantile(0.25)
q3=Fh['histogram_min'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d13=Fh[Fh['histogram_min']<low].values
d14=Fh[Fh['histogram_min']>high].values
Fh['histogram_min'].replace(d13,low,inplace=True)
Fh['histogram_min'].replace(d14,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_min'])
# Out:
# <AxesSubplot:xlabel='histogram_min'>

# %%
q1=Fh['histogram_number_of_zeroes'].quantile(0.25)
q3=Fh['histogram_number_of_zeroes'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d15=Fh[Fh['histogram_number_of_zeroes']<low].values
d16=Fh[Fh['histogram_number_of_zeroes']>high].values
Fh['histogram_number_of_zeroes'].replace(d15,low,inplace=True)
Fh['histogram_number_of_zeroes'].replace(d16,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_number_of_zeroes'])
# Out:
# <AxesSubplot:xlabel='histogram_number_of_zeroes'>

# %%
q1=Fh['histogram_number_of_peaks'].quantile(0.25)
q3=Fh['histogram_number_of_peaks'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d17=Fh[Fh['histogram_number_of_peaks']<low].values
d18=Fh[Fh['histogram_number_of_peaks']>high].values
Fh['histogram_number_of_peaks'].replace(d17,low,inplace=True)
Fh['histogram_number_of_peaks'].replace(d18,high,inplace=True)

# %%
sns.boxplot(Fh['histogram_number_of_peaks'])
# Out:
# <AxesSubplot:xlabel='histogram_number_of_peaks'>

# %%
q1=Fh['mean_value_of_long_term_variability'].quantile(0.25)
q3=Fh['mean_value_of_long_term_variability'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d17=Fh[Fh['mean_value_of_long_term_variability']<low].values
d18=Fh[Fh['mean_value_of_long_term_variability']>high].values
Fh['mean_value_of_long_term_variability'].replace(d17,low,inplace=True)
Fh['mean_value_of_long_term_variability'].replace(d18,high,inplace=True)

# %%
sns.boxplot(Fh['mean_value_of_long_term_variability'])
# Out:
# <AxesSubplot:xlabel='mean_value_of_long_term_variability'>

# %%
q1=Fh['percentage_of_time_with_abnormal_long_term_variability'].quantile(0.25)
q3=Fh['percentage_of_time_with_abnormal_long_term_variability'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d19=Fh[Fh['percentage_of_time_with_abnormal_long_term_variability']<low].values
d20=Fh[Fh['percentage_of_time_with_abnormal_long_term_variability']>high].values
Fh['percentage_of_time_with_abnormal_long_term_variability'].replace(d19,low,inplace=True)
Fh['percentage_of_time_with_abnormal_long_term_variability'].replace(d20,high,inplace=True)

# %%
sns.boxplot(Fh['percentage_of_time_with_abnormal_long_term_variability'])
# Out:
# <AxesSubplot:xlabel='percentage_of_time_with_abnormal_long_term_variability'>

# %%
q1=Fh['mean_value_of_short_term_variability'].quantile(0.25)
q3=Fh['mean_value_of_short_term_variability'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d21=Fh[Fh['mean_value_of_short_term_variability']<low].values
d22=Fh[Fh['mean_value_of_short_term_variability']>high].values
Fh['mean_value_of_short_term_variability'].replace(d21,low,inplace=True)
Fh['mean_value_of_short_term_variability'].replace(d22,high,inplace=True)

# %%
sns.boxplot(Fh['mean_value_of_short_term_variability'])
# Out:
# <AxesSubplot:xlabel='mean_value_of_short_term_variability'>

# %%
q1=Fh['abnormal_short_term_variability'].quantile(0.25)
q3=Fh['abnormal_short_term_variability'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d23=Fh[Fh['abnormal_short_term_variability']<low].values
d24=Fh[Fh['abnormal_short_term_variability']>high].values
Fh['abnormal_short_term_variability'].replace(d23,low,inplace=True)
Fh['abnormal_short_term_variability'].replace(d24,high,inplace=True)

# %%
sns.boxplot(Fh['abnormal_short_term_variability'])
# Out:
# <AxesSubplot:xlabel='abnormal_short_term_variability'>

# %%
q1=Fh['prolongued_decelerations'].quantile(0.25)
q3=Fh['prolongued_decelerations'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d25=Fh[Fh['prolongued_decelerations']<low].values
d26=Fh[Fh['prolongued_decelerations']>high].values
Fh['prolongued_decelerations'].replace(d25,low,inplace=True)
Fh['prolongued_decelerations'].replace(d26,high,inplace=True)

# %%
sns.boxplot(Fh['prolongued_decelerations'])
# Out:
# <AxesSubplot:xlabel='prolongued_decelerations'>

# %%
q1=Fh['severe_decelerations'].quantile(0.25)
q3=Fh['severe_decelerations'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d27=Fh[Fh['severe_decelerations']<low].values
d28=Fh[Fh['severe_decelerations']>high].values
Fh['severe_decelerations'].replace(d27,low,inplace=True)
Fh['severe_decelerations'].replace(d28,high,inplace=True)

# %%
sns.boxplot(Fh['severe_decelerations'])
# Out:
# <AxesSubplot:xlabel='severe_decelerations'>

# %%
q1=Fh['light_decelerations'].quantile(0.25)
q3=Fh['light_decelerations'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d29=Fh[Fh['light_decelerations']<low].values
d30=Fh[Fh['light_decelerations']>high].values
Fh['light_decelerations'].replace(d29,low,inplace=True)
Fh['light_decelerations'].replace(d30,high,inplace=True)

# %%
sns.boxplot(Fh['light_decelerations'])
# Out:
# <AxesSubplot:xlabel='light_decelerations'>

# %%
q1=Fh['uterine_contractions'].quantile(0.25)
q3=Fh['uterine_contractions'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d31=Fh[Fh['uterine_contractions']<low].values
d32=Fh[Fh['uterine_contractions']>high].values
Fh['uterine_contractions'].replace(d31,low,inplace=True)
Fh['uterine_contractions'].replace(d32,high,inplace=True)

# %%
sns.boxplot(Fh['uterine_contractions'])
# Out:
# <AxesSubplot:xlabel='uterine_contractions'>

# %%
q1=Fh['fetal_movement'].quantile(0.25)
q3=Fh['fetal_movement'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d33=Fh[Fh['fetal_movement']<low].values
d34=Fh[Fh['fetal_movement']>high].values
Fh['fetal_movement'].replace(d33,low,inplace=True)
Fh['fetal_movement'].replace(d34,high,inplace=True)

# %%
sns.boxplot(Fh['fetal_movement'])
# Out:
# <AxesSubplot:xlabel='fetal_movement'>

# %%
q1=Fh['accelerations'].quantile(0.25)
q3=Fh['accelerations'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d35=Fh[Fh['accelerations']<low].values
d36=Fh[Fh['accelerations']>high].values
Fh['accelerations'].replace(d35,low,inplace=True)
Fh['accelerations'].replace(d36,high,inplace=True)

# %%
sns.boxplot(Fh['accelerations'])
# Out:
# <AxesSubplot:xlabel='accelerations'>

# %%
q1=Fh['baseline value'].quantile(0.25)
q3=Fh['baseline value'].quantile(0.75)
iqr=q3-q1
low=q1-(1.5*iqr)
high=q3+(1.5*iqr)
d37=Fh[Fh['baseline value']<low].values
d38=Fh[Fh['baseline value']>high].values
Fh['baseline value'].replace(d37,low,inplace=True)
Fh['baseline value'].replace(d38,high,inplace=True)

# %%
sns.boxplot(Fh['baseline value'])
# Out:
# <AxesSubplot:xlabel='baseline value'>

# %% [markdown]
# #  Qualitative analysis

# %%
f1=pd.crosstab(index=Fh['severe_decelerations' ],columns='counts')
f1
# Out:
# col_0                 counts
# severe_decelerations
# 0.0                     2126

# %%
freq1 =f1.sum()
freq1
# Out:
# col_0
# counts    2126
# dtype: int64

# %%
f2=pd.crosstab(index=Fh['prolongued_decelerations' ],columns='counts')
f2

freq2 = f2.sum()
freq2
# Out:
# col_0
# counts    2126
# dtype: int64

# %%
Fh['prolongued_decelerations'].mode()[0]
# Out:
# 0.0

# %%
f3=pd.crosstab(index=Fh['histogram_tendency'],columns='counts')
f3
# Out:
# col_0               counts
# histogram_tendency
# -1.0                   165
#  0.0                  1115
#  1.0                   846

# %%
freq3 = f3.sum()
freq3
# Out:
# col_0
# counts    2126
# dtype: int64

# %%
f4=pd.crosstab(index=Fh['histogram_number_of_zeroes'],columns='counts')
f4
# Out:
# col_0                       counts
# histogram_number_of_zeroes
# 0.0                           2126

# %% [markdown]
# # Data scaling

# %%
x=Fh.iloc[:,0:21]
x.head(5)
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.015          0.0075                0.0145
# 1           132.0          0.006          0.0075                0.0060
# 2           133.0          0.003          0.0075                0.0080
# 3           134.0          0.003          0.0075                0.0080
# 4           132.0          0.015          0.0075                0.0080
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0               0.0075                   0.0                       0.0
# 1               0.0075                   0.0                       0.0
# 2               0.0075                   0.0                       0.0
# 3               0.0075                   0.0                       0.0
# 4               0.0075                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
y=Fh.iloc[:,-1]
y.head(7)
# Out:
# 0    2.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    3.0
# 6    3.0
# Name: fetal_health, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
d01=scaler.fit_transform(x)

# %%
d01
# Out:
# array([[0.25925926, 1.        , 0.        , ..., 0.        , 1.        ,
#         1.        ],
#        [0.48148148, 0.25      , 0.        , ..., 0.51973684, 1.        ,
#         0.5       ],
#        [0.5       , 0.        , 0.        , ..., 0.49342105, 1.        ,
#         0.5       ],
#        ...,
#        [0.62962963, 1.        , 0.        , ..., 0.67763158, 1.        ,
#         1.        ],
#        [0.62962963, 1.        , 0.        , ..., 1.        , 1.        ,
#         1.        ],
#        [0.66666667, 1.        , 0.        , ..., 0.        , 1.        ,
#         0.5       ]])

# %% [markdown]
# #  Data Partion

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
x_train.shape
# Out:
# (1488, 21)

# %%
y_train.shape
# Out:
# (1488,)

# %%
x_test.shape
# Out:
# (638, 21)

# %%
y_test.shape
# Out:
# (638,)

# %% [markdown]
#  # checking balance

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE()

# %%
x_train,y_train=smote.fit_resample(x_train,y_train)
x_test,y_test=smote.fit_resample(x_test,y_test)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (3483, 21) (3483,) (1482, 21) (1482,)

# %%
Fh.corr()
# Out:
#                                                     baseline value  \
# baseline value                                            1.000000
# accelerations                                             0.096373
# fetal_movement                                                 NaN
# uterine_contractions                                      0.025899
# light_decelerations                                            NaN
# severe_decelerations                                           NaN
# prolongued_decelerations                                       NaN
# abnormal_short_term_variability                           0.305570
# mean_value_of_short_term_variability                     -0.057858
# percentage_of_time_with_abnormal_long_term_vari...             NaN
# mean_value_of_long_term_variability                      -0.113244
# histogram_width                                          -0.147679
# histogram_min                                             0.361619
# ...

# %%
plt.figure(figsize=(14,10))
corr=Fh.corr()
a=sns.heatmap(corr,cmap='RdGy',annot=True,linewidths=2.0)
plt.show()

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()
data = logistic.fit(x_train,y_train)
y1_pred=logistic.predict(x_test)

# %%
y1_pred.shape
# Out:
# (1482,)

# %%
y_test.shape
# Out:
# (1482,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm1=confusion_matrix(y1_pred,y_test)
acc1=accuracy_score(y1_pred,y_test)

# %%
cm1
# Out:
# array([[334,  68,  36],
#        [ 84, 339,  97],
#        [ 76,  87, 361]], dtype=int64)

# %%
acc1
# Out:
# 0.6977058029689609

# %%
from sklearn import metrics
precision_positive1= metrics.precision_score(y_test,y1_pred,pos_label=1,average='micro')
precision_negative1=metrics.precision_score(y_test,y1_pred,pos_label=0,average='micro')
print(precision_positive1,precision_negative1)
# Out:
# 0.6977058029689609 0.6977058029689609

# %%
recall_sensitivity=metrics.recall_score(y_test,y1_pred,pos_label=1,average='micro')
recall_specificity=metrics.recall_score(y_test,y1_pred,pos_label=0,average='micro')
print(recall_sensitivity,recall_specificity)
# Out:
# 0.6977058029689609 0.6977058029689609

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=3)
data1=classifier.fit(x_train,y_train)
y2_pred=classifier.predict(x_test)
y2_pred.shape
# Out:
# (1482,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm2=confusion_matrix(y2_pred,y_test)
acc2=accuracy_score(y2_pred,y_test)

# %%
cm2
# Out:
# array([[413, 101,  58],
#        [ 54, 317,  38],
#        [ 27,  76, 398]], dtype=int64)

# %%
acc2
# Out:
# 0.7611336032388664

# %%
from sklearn import metrics
precision_positive2 = metrics.precision_score(y_test,y2_pred,pos_label=1,average='micro')
precision_negative2=metrics.precision_score(y_test,y2_pred,pos_label=0,average='micro')
print(precision_positive2,precision_negative2)
# Out:
# 0.7611336032388664 0.7611336032388664

# %%
recall_sensitivity1=metrics.recall_score(y_test,y2_pred,pos_label=1,average='micro')
recall_specificity1=metrics.recall_score(y_test,y2_pred,pos_label=0,average='micro')
print(recall_sensitivity1,recall_specificity1)
# Out:
# 0.7611336032388664 0.7611336032388664

# %%
from sklearn.svm import SVC
classifier2=SVC(kernel='poly')
data2=classifier2.fit(x_train,y_train)
y3_pred=classifier.predict(x_test)
y3_pred.shape
# Out:
# (1482,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm3=confusion_matrix(y3_pred,y_test)
acc3=accuracy_score(y3_pred,y_test)

# %%
cm3
# Out:
# array([[413, 101,  58],
#        [ 54, 317,  38],
#        [ 27,  76, 398]], dtype=int64)

# %%
acc3
# Out:
# 0.7611336032388664

# %%
from sklearn import metrics
precision_positive3= metrics.precision_score(y_test,y3_pred,pos_label=1,average='micro')
precision_negative3=metrics.precision_score(y_test,y3_pred,pos_label=0,average='micro')
print(precision_positive3,precision_negative3)
# Out:
# 0.7611336032388664 0.7611336032388664

# %%
recall_sensitivity2=metrics.recall_score(y_test,y3_pred,pos_label=1,average='micro')
recall_specificity2=metrics.recall_score(y_test,y3_pred,pos_label=0,average='micro')
print(recall_sensitivity2,recall_specificity2)
# Out:
# 0.7611336032388664 0.7611336032388664

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion='entropy')
data3=tree.fit(x_train,y_train)
y4_pred=tree.predict(x_test)
y4_pred.shape
# Out:
# (1482,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm4=confusion_matrix(y4_pred,y_test)
acc4=accuracy_score(y4_pred,y_test)

# %%
cm4
# Out:
# array([[444, 112,  59],
#        [ 38, 325,  54],
#        [ 12,  57, 381]], dtype=int64)

# %%
acc4
# Out:
# 0.7759784075573549

# %%
from sklearn import metrics
precision_positive4= metrics.precision_score(y_test,y4_pred,pos_label=1,average='micro')
precision_negative4=metrics.precision_score(y_test,y4_pred,pos_label=0,average='micro')
print(precision_positive4,precision_negative4)
# Out:
# 0.7759784075573549 0.7759784075573549

# %%
recall_sensitivity3=metrics.recall_score(y_test,y4_pred,pos_label=1,average='micro')
recall_specificity3=metrics.recall_score(y_test,y4_pred,pos_label=0,average='micro')
print(recall_sensitivity3,recall_specificity3)
# Out:
# 0.7759784075573549 0.7759784075573549

# %%
from sklearn.ensemble import RandomForestClassifier
classifier5=RandomForestClassifier(criterion='entropy')
data4=classifier5.fit(x_train,y_train)
y5_pred=classifier5.predict(x_test)
y5_pred.shape
# Out:
# (1482,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm5=confusion_matrix(y5_pred,y_test)
acc5=accuracy_score(y5_pred,y_test)

# %%
cm5
# Out:
# array([[469, 100,  17],
#        [ 20, 373,  43],
#        [  5,  21, 434]], dtype=int64)

# %%
acc5
# Out:
# 0.8609986504723347

# %%
from sklearn import metrics
precision_positive5= metrics.precision_score(y_test,y5_pred,pos_label=1,average='micro')
precision_negative5=metrics.precision_score(y_test,y5_pred,pos_label=0,average='micro')
print(precision_positive5,precision_negative5)
# Out:
# 0.8609986504723347 0.8609986504723347

# %%
recall_sensitivity4=metrics.recall_score(y_test,y5_pred,pos_label=1,average='micro')
recall_specificity4=metrics.recall_score(y_test,y5_pred,pos_label=0,average='micro')
print(recall_sensitivity4,recall_specificity4)
# Out:
# 0.8609986504723347 0.8609986504723347

# %%
from sklearn.naive_bayes import GaussianNB
navie=GaussianNB()
data6=navie.fit(x_train,y_train)
y6_pred=navie.predict(x_test)
y6_pred.shape
# Out:
# (1482,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm6=confusion_matrix(y6_pred,y_test)
acc6=accuracy_score(y6_pred,y_test)

# %%
cm6
# Out:
# array([[291,  32,  33],
#        [120, 418, 114],
#        [ 83,  44, 347]], dtype=int64)

# %%
acc6
# Out:
# 0.7125506072874493

# %%
from sklearn import metrics
precision_positive6= metrics.precision_score(y_test,y6_pred,pos_label=1,average='micro')
precision_negative6=metrics.precision_score(y_test,y6_pred,pos_label=0,average='micro')
print(precision_positive6,precision_negative6)
# Out:
# 0.7125506072874493 0.7125506072874493

# %%
recall_sensitivity5=metrics.recall_score(y_test,y6_pred,pos_label=1,average='micro')
recall_specificity5=metrics.recall_score(y_test,y6_pred,pos_label=0,average='micro')
print(recall_sensitivity5,recall_specificity5)
# Out:
# 0.7125506072874493 0.7125506072874493

# %% [markdown]
# ## out of all models we get High accuracy at Random Forest
